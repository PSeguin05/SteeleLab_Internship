# %% [markdown]
# # Computation of the mode frequencies in the cavity

# %%
import Resonant_modes_Cavity_filter as Resmodes
# Out:
# c:\Users\Pacome\Documents\Scolarite\ENS_de_Lyon\Departement_Physique\M1_SDM\Stage\Travail\Code\internship-pacome\Resonant_modes_Cavity_filter.py:164: SyntaxWarning: invalid escape sequence '\p'
#   ax_phase.set_yticklabels(["$-\pi$", "$0$", "$\pi$"])
# c:\Users\Pacome\Documents\Scolarite\ENS_de_Lyon\Departement_Physique\M1_SDM\Stage\Travail\Code\internship-pacome\Resonant_modes_Cavity_filter.py:164: SyntaxWarning: invalid escape sequence '\p'
#   ax_phase.set_yticklabels(["$-\pi$", "$0$", "$\pi$"])
# c:\Users\Pacome\Documents\Scolarite\ENS_de_Lyon\Departement_Physique\M1_SDM\Stage\Travail\Code\internship-pacome\Resonant_modes_Cavity_filter.py:182: SyntaxWarning: invalid escape sequence '\k'
#   f"Signal $S_{{21}}$ — Cylindric Microwave Cavity\n $f_0 = {f_0 * 1e-9:.2f}$ GHz | $Q_0 = {Q_0:,}$ | $\kappa_0 = {kappa_0*1e-6:.2f}$ MHz | $Q_e = {Q_ex:,}$ | $\kappa_e = {kappa_ex*1e-6:.2f} MHz$\n {regime}", fontsize=10, y=1, linespacing=1.6,
# ...

# %% [markdown]
# ## $R=2.5$ cm

# %%
Resmodes.plot_cavity_transversal_modes(L_min = 6e-2, 
                                       L_max = 12e-2,
                                       Delta_L = 1e-4,
                                       R = 2.5e-2, 
                                       T_mode = "TM")

# %%
Resmodes.plot_cavity_transversal_modes(L_min = 6e-2, 
                                       L_max = 12e-2,
                                       Delta_L = 1e-4,
                                       R = 2.5e-2, 
                                       T_mode = "TE")

# %% [markdown]
# ## Compute S21

# %%
Resmodes.plot_S21(5e9, 1e4, 1e3, 10000)
